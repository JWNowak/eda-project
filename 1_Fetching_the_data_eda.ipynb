# %% [markdown]
# # SQL in Python - Connecting to and retrieving data from PostgreSQL
#
# Previously, you have learned how to connect to a SQL database by using a SQL client such as DBeaver. Apart from connecting to databases, DBeaver also allows you to run SQL queries against the database, create new tables and populate them with data as well as retrieving the data.
#
# Python also allows executing SQL queries and getting the result into a Python object, for example a Pandas data frame. Instead of exporting a .csv file from DBeaver you can directly get the data you need into Python and continue your work. In addition we can reduce the steps by connecting to the database from Python directly, eliminating the need for a separate SQL client.
#
# After you have the data in Python in the required shape you can export the data into a .csv file. This file is for your own reference, please avoid sending .csv files around - database is the point of reference when it comes to data.
#
# Having a copy of a .csv file (or another format) can speed up your analysis work. Imagine that the query takes 25 minutes to run. If you made some mistakes in your Python code you might need to go back to the original dataset. Instead of having to rerun the SQL query and having to wait you can read in the .csv file you have previously saved on your hard disk into Python and continue with your analysis work.
#
# **In this notebook you will see 2 ways to connect to SQL-Databases and export the data to a CSV file**

# %% [markdown]
# ## Creating a connection to a PostgreSQL database with Python

# %% [markdown]
# There are 2 python packages that are the "go-to" when it comes to connecting to SQL-Databases: `psycopg2` and `sqlalchemy`

# %% [markdown]
# ### Connecting via psycopg2

# %%
import pandas as pd
import psycopg2

# %% [markdown]
# In order to create a connection to our PostgreSQL database we need the following information:
#
# - host = the address of the machine the database is hosted on
# - port = the virtual gate number through which communication will be allowed
# - database = the name of the database
# - user = the name of the user
# - password = the password of the user
#
# Because we don't want that the database information is published on github we put it into a `.env` file which is added into the `.gitignore`.
# In these kind of files you can store information that is not supposed to be published.
# With the `dotenv` package you can read the `.env` files and get the variables.
# (We will share the file with you on Slack!)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

DATABASE = os.getenv('DATABASE')
USER_DB = os.getenv('USER_DB')
PASSWORD = os.getenv('PASSWORD')
HOST = os.getenv('HOST')
PORT = os.getenv('PORT')

# %% [markdown]
# The function from the psycopg2 package to create a connection is called `connect()`.
# `connect()` expects the parameters listed above as input in order to connect to the database.

# %%
# Create connection object conn
conn = psycopg2.connect(
    database=DATABASE,
    user=USER_DB,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# %% [markdown]
# ### Retrieving data from the database with psycopg2
#
# Before we can use our connection to get data, we have to create a cursor. A cursor allows Python code to execute PostgreSQL commmands in a database session.
# A cursor has to be created with the `cursor()` method of our connection object conn.

# %%
cur = conn.cursor()

# %% [markdown]
# Now we can run SQL-Queries with `cur.execute('QUERY')` and then run `cur.fetchall()` to get the data:

# %%
cur.execute('SELECT * FROM eda.king_county_house_sales LIMIT 10')
cur.fetchall()
# Out:
# [(datetime.date(2014, 10, 13), 221900.0, 7129300520, 1),
#  (datetime.date(2014, 12, 9), 538000.0, 6414100192, 2),
#  (datetime.date(2015, 2, 25), 180000.0, 5631500400, 3),
#  (datetime.date(2014, 12, 9), 604000.0, 2487200875, 4),
#  (datetime.date(2015, 2, 18), 510000.0, 1954400510, 5),
#  (datetime.date(2014, 5, 12), 1230000.0, 7237550310, 6),
#  (datetime.date(2014, 6, 27), 257500.0, 1321400060, 7),
#  (datetime.date(2015, 1, 15), 291850.0, 2008000270, 8),
#  (datetime.date(2015, 4, 15), 229500.0, 2414600126, 9),
#  (datetime.date(2015, 3, 12), 323000.0, 3793500160, 10)]

# %% [markdown]
# With `conn.close()` you can close the connection again.

# %%
#close the connection
conn.close()

# %% [markdown]
# But we want to work with the data. The easiest way is to import the data into pandas dataframes. We can use `pd.read_sql_query` or `pd.read_sql_table` or for convenience `pd.read_sql`.
#
# This function is a convenience wrapper around read_sql_table and read_sql_query (for backward compatibility). It will delegate to the specific function depending on the provided input. A SQL query will be routed to read_sql_query , while a database table name will be routed to read_sql_table . Note that the delegated function might have more specific notes about their functionality not listed here.

# %%
# Open connection again because we closed it
conn = psycopg2.connect(
    database=DATABASE,
    user=USER_DB,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# %%
# import the data into a pandas dataframe
query_string = "SELECT * FROM eda.king_county_house_sales LIMIT 10"
df_psycopg = pd.read_sql(query_string, conn)
# Out:
# /var/folders/yq/ygxpmd3j5pq7tmf46p9cp4dm0000gn/T/ipykernel_93533/1176423828.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_psycopg = pd.read_sql(query_string, conn)

# %%
#close the connection
conn.close()

# %%
df_psycopg.head()
# Out:
#          date     price    house_id  id
# 0  2014-10-13  221900.0  7129300520   1
# 1  2014-12-09  538000.0  6414100192   2
# 2  2015-02-25  180000.0  5631500400   3
# 3  2014-12-09  604000.0  2487200875   4
# 4  2015-02-18  510000.0  1954400510   5

# %%
#export the data to a csv-file
df_psycopg.to_csv('data/eda.csv',index=False)

# %% [markdown]
# ### Connecting and retrieving data via SQLAlchemy
#
# `sqlalchemy` works similarly. Here you have to create an engine with the database sting (a link that includes every information we entered in the conn object)

# %%
from sqlalchemy import create_engine

#read the database string from the .env
load_dotenv()

DB_STRING = os.getenv('DB_STRING')

db = create_engine(DB_STRING)

# %% [markdown]
# And then you can import that engine with a query into a pandas dataframe.

# %%
#import the data to a pandas dataframe
query_string = "SELECT * FROM eda.king_county_house_sales"
df_sqlalchemy1 = pd.read_sql(query_string, db)

# %%
#import the data to a pandas dataframe
query_string = "SELECT * FROM eda.king_county_house_details"
df_sqlalchemy2 = pd.read_sql(query_string, db)

# %%
#import the data to a pandas dataframe
query_string = 'select kchd.*,kchs."date" ,kchs.price from eda.king_county_house_details kchd left join eda.king_county_house_sales kchs on kchd.id = kchs.house_id'
df_sqlalchemy3 = pd.read_sql(query_string, db)

# %%
df_sqlalchemy1.head()
# Out:
#          date     price    house_id  id
# 0  2014-10-13  221900.0  7129300520   1
# 1  2014-12-09  538000.0  6414100192   2
# 2  2015-02-25  180000.0  5631500400   3
# 3  2014-12-09  604000.0  2487200875   4
# 4  2015-02-18  510000.0  1954400510   5

# %%
df_sqlalchemy2.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0     1000102       6.0        3.0       2400.0    9373.0     2.0         NaN
# 1   100100050       3.0        1.0       1320.0   11090.0     1.0         0.0
# 2  1001200035       3.0        1.0       1350.0    7973.0     1.5         NaN
# 3  1001200050       4.0        1.5       1260.0    7248.0     1.5         NaN
# 4  1003000175       3.0        1.0        980.0    7606.0     1.0         0.0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0   0.0          3      7      2400.0            0.0      1991           0.0
# 1   0.0          3      7      1320.0            0.0      1955           0.0
# 2   0.0          3      7      1350.0            0.0      1954           0.0
# 3   0.0          5      7      1260.0            0.0      1955           NaN
# 4   0.0          3      7       980.0            0.0      1954           0.0
#
# ...

# %%
df_sqlalchemy3.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520       3.0       1.00       1180.0    5650.0     1.0         NaN
# 1  6414100192       3.0       2.25       2570.0    7242.0     2.0         0.0
# 2  5631500400       2.0       1.00        770.0   10000.0     1.0         0.0
# 3  2487200875       4.0       3.00       1960.0    5000.0     1.0         0.0
# 4  1954400510       3.0       2.00       1680.0    8080.0     1.0         0.0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0   0.0          3      7  ...            0.0      1955           0.0
# 1   0.0          3      7  ...          400.0      1951       19910.0
# 2   0.0          3      6  ...            0.0      1933           NaN
# 3   0.0          5      7  ...          910.0      1965           0.0
# 4   0.0          3      8  ...            0.0      1987           0.0
#
# ...

# %% [markdown]
# Because we don't want to run the queries over and over again we can export the data into a .csv file in order to use it in other notebooks as well.

# %%
#export the data to a csv-file
df_sqlalchemy1.to_csv('king_county_house_sales.csv',index=False)

# %%
#export the data to a csv-file
df_sqlalchemy2.to_csv('king_county_house_details.csv',index=False)

# %%
#export the data to a csv-file
df_sqlalchemy3.to_csv('king_county_house_total.csv',index=False)

# %%
# Import python packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the data as pandas dataframe (from a csv-file)
df_sales = pd.read_csv('data/king_county_house_sales.csv')
df_details = pd.read_csv('data/king_county_house_details.csv')
df_data = pd.read_csv('data/king_county_house_total.csv')

# %%
df_sales.info()
df_sales.head(5)

# %%
df_details.info()
df_details.head(5)

# %%
df_data.info()
df_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   bedrooms       21597 non-null  float64
#  2   bathrooms      21597 non-null  float64
#  3   sqft_living    21597 non-null  float64
#  4   sqft_lot       21597 non-null  float64
#  5   floors         21597 non-null  float64
#  6   waterfront     19206 non-null  float64
#  7   view           21534 non-null  float64
#  8   condition      21597 non-null  int64
#  9   grade          21597 non-null  int64
#  10  sqft_above     21597 non-null  float64
#  11  sqft_basement  21145 non-null  float64
#  12  yr_built       21597 non-null  int64
#  13  yr_renovated   17749 non-null  float64
#  14  zipcode        21597 non-null  int64
#  15  lat            21597 non-null  float64
#  16  long           21597 non-null  float64
# ...

# %%
# Check for missing data in dataframe
df_nan_count = df_data.isna().sum().sort_values(ascending=False)
df_nan_ratio = df_data.isna().mean().sort_values(ascending=False)*100

print(df_nan_count)
print(df_nan_ratio)
# Out:
# yr_renovated     3848
# waterfront       2391
# sqft_basement     452
# view               63
# id                  0
# yr_built            0
# date                0
# sqft_lot15          0
# sqft_living15       0
# long                0
# lat                 0
# zipcode             0
# sqft_above          0
# bedrooms            0
# grade               0
# condition           0
# floors              0
# sqft_lot            0
# sqft_living         0
# bathrooms           0
# price               0
# dtype: int64
# yr_renovated     17.817289
# waterfront       11.070982
# sqft_basement     2.092883
# view              0.291707
# id                0.000000
# yr_built          0.000000
# date              0.000000
# sqft_lot15        0.000000
# sqft_living15     0.000000
# long              0.000000
# lat               0.000000
# zipcode           0.000000
# sqft_above        0.000000
# bedrooms          0.000000
# grade             0.000000
# condition         0.000000
# ...

# %%
# Clean relevant data

# Include renovation status
is_nan = df_data["yr_renovated"].isna()
df_data["is_renovated"] = ~is_nan

# Clean renovation year
df_data["yr_renovated"] = df_data.yr_renovated[~is_nan]/10
df_data.head(5)
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520       3.0       1.00       1180.0    5650.0     1.0         NaN
# 1  6414100192       3.0       2.25       2570.0    7242.0     2.0         0.0
# 2  5631500400       2.0       1.00        770.0   10000.0     1.0         0.0
# 3  2487200875       4.0       3.00       1960.0    5000.0     1.0         0.0
# 4  1954400510       3.0       2.00       1680.0    8080.0     1.0         0.0
#
#    view  condition  grade  ...  yr_built  yr_renovated  zipcode      lat  \
# 0   0.0          3      7  ...      1955           0.0    98178  47.5112
# 1   0.0          3      7  ...      1951        1991.0    98125  47.7210
# 2   0.0          3      6  ...      1933           NaN    98028  47.7379
# 3   0.0          5      7  ...      1965           0.0    98136  47.5208
# 4   0.0          3      8  ...      1987           0.0    98074  47.6168
#
# ...

# %%
# Plot average house price per zipcode
p = sns.barplot(x="zipcode", y="price", errorbar="ci", data=df_data)
p.set_title("House price per zipcode")
p.set_xlabel("Zipcode")
p.set_ylabel("Price ($)")
plt.show()

#color = sns.color_palette("husl",5)
#sns.set_palette(color)

# Plot house price per condition
#p = sns.boxplot(x="condition", y="price", data=df_data)
#p.set_title("House price per condition")
#p.set_xlabel("Condition")
#p.set_ylabel("Price ($)")
#plt.show()

color = sns.color_palette("husl",11)
sns.set_palette(color)

# Plot house price per grade
p = sns.boxplot(x="grade", y="price", data=df_data)
p.set_title("House price per grade")
p.set_xlabel("Grade")
p.set_ylabel("Price ($)")
plt.show()

color = sns.color_palette("husl",5)
sns.set_palette(color)

# Plot house price per grade and condition
p = sns.boxplot(x="grade", y="price", hue="condition", data=df_data)
p.set_title("House price per grade")
p.set_xlabel("Grade")
p.set_ylabel("Price ($)")
plt.show()

# %%
# Define historic buildings by age
building_age = 1950

# Extract data for historic buildings
df = df_data[df_data["yr_built"] <= building_age]
building_age_max = df["yr_built"].max()
building_age_min = df["yr_built"].min()

# Add era information
eras = ["1900 - 1910", "1910 - 1920", "1920 - 1930", "1930 - 1940", "1940 - 1950"]
df["era"] = pd.cut(df["yr_built"], bins=5, labels=eras)
eras_num = [1, 2, 3, 4, 5]
df["era_num"] = pd.cut(df["yr_built"], bins=5, labels=eras_num)

# Add information grade of historic buildings
building_grade = 9
df["is_best_grade"] = df["grade"] >= building_grade

df.head(5)

# %%
# Add date information

import datetime as dt
from datetime import datetime, date, time, timedelta

df['date'] = pd.to_datetime(df['date'])
df['date_year'] = df['date'].dt.year
df['date_month'] = df['date'].dt.month

df.head(5)

# %%
df['date'].max()
# Out:
# Timestamp('2015-05-27 00:00:00')

# %%
# PROFIT / PRICE *** VERSION 1 ***
color = sns.color_palette("husl",5)
sns.set_palette(color)

# Plot house price per condition
p = sns.boxplot(x="condition", y="price", data=df)
p.set_title(f"House price per condition ({building_age_min} - {building_age_max})")
p.set_xlabel("Condition")
p.set_ylabel("Price ($)")
plt.ylim(0,8000000)
plt.show()

color = sns.color_palette("husl",12)
sns.set_palette(color)

# Plot house price per grade
p = sns.boxplot(x="grade", y="price", data=df)
p.set_title(f"House price per grade ({building_age_min} - {building_age_max})")
p.set_xlabel("Grade")
p.set_ylabel("Price ($)")
plt.ylim(0,8000000)
plt.show()

color = sns.color_palette("husl",5)
sns.set_palette(color)

# Plot house price per grade and condition
p = sns.boxplot(x="grade", y="price", hue="condition", data=df)
p.set_title(f"House price per grade ({building_age_min} - {building_age_max})")
p.set_xlabel("Grade")
p.set_ylabel("Price ($)")
plt.show()

color = sns.color_palette("husl",5)
sns.set_palette(color)

# Plot house price per era
p = sns.boxplot(x="era", y="price", data=df)
p.set_title(f"House price per era ({building_age_min} - {building_age_max})")
p.set_xlabel("Era")
p.set_ylabel("Price ($)")
plt.ylim(0,8000000)
plt.show()

# %%
# PROFIT / PRICE *** VERSION 2 ***
color = sns.color_palette("BuGn",5)
sns.set_palette(color)

# Plot house price per condition
p = sns.barplot(x="condition", y="price", errorbar="ci", data=df)
p.set_title(f"House price per condition ({building_age_min} - {building_age_max})")
p.set_xlabel("Condition")
p.set_ylabel("Price ($)")
plt.ylim(0,5000000)
plt.show()
fig = p.get_figure()
fig.savefig("price_per_condition.png") 

color = sns.color_palette("BuGn",11)
sns.set_palette(color)

# Plot house price per grade
p = sns.barplot(x="grade", y="price", errorbar="ci", data=df)
p.set_title(f"House price per grade ({building_age_min} - {building_age_max})")
p.set_xlabel("Grade")
p.set_ylabel("Price ($)")
plt.ylim(0,5000000)
plt.show()
fig = p.get_figure()
fig.savefig("price_per_grade.png") 

#color = sns.color_palette("cividis_r",5)
#sns.set_palette(color)

# Plot house price per grade and condition
#p = sns.barplot(x="grade", y="price", hue="condition", data=df)
#p.set_title(f"House price per grade ({building_age_min} - {building_age_max})")
#p.set_xlabel("Grade")
#p.set_ylabel("Price ($)")
#plt.ylim(0,5000000)
#plt.show()

color = sns.color_palette("BuGn",5)
sns.set_palette(color)

# Plot house price per era
p = sns.barplot(x="era", y="price", errorbar="ci", data=df)
p.set_title(f"House price per era ({building_age_min} - {building_age_max})")
p.set_xlabel("Era")
p.set_ylabel("Price ($)")
plt.ylim(0,5000000)
plt.show()
fig = p.get_figure()
fig.savefig("price_per_era.png") 

color = sns.color_palette("BrBG",2)
sns.set_palette(color)

# Plot house price per renovation
p = sns.barplot(x="is_renovated", y="price", errorbar="ci", data=df)
p.set_title(f"House price per renovation ({building_age_min} - {building_age_max})")
p.set_xlabel("Renovated (True/False)")
p.set_ylabel("Price ($)")
plt.ylim(0,5000000)
plt.show()
fig = p.get_figure()
fig.savefig("price_per_renovation.png")

# %%
# NEIGHBORHOOD / ZIPCODE
color = sns.color_palette("Greys",70)
sns.set_palette(color)

# Plot: House count per zipcode ( 1900 - 1950)
p = sns.countplot(y="zipcode", data=df)
p.set_title(f"House count per zipcode ({building_age_min} - {building_age_max})")
p.set_xlabel("Count")
p.set_ylabel("Zipcode")
plt.show()
fig = p.get_figure()
fig.savefig("house_per_zip.png") 

color = sns.color_palette(["#bdbdbd"])
sns.set_palette(color)

p = sns.jointplot(x="lat", y="long", kind="kde", data=df)
#p.set_title(f"Houses ({building_age_min} - {building_age_max})")
p.set_axis_labels("Latidude (°)", "Longitude (°)")
plt.show()
p.savefig("house_per_area.png")

# %%
# NEIGHBORHOOD / ZIPCODE
color = sns.color_palette("BuGn",35)
sns.set_palette(color)

new_df = df[df["is_best_grade"] == True]
# Plot: House count per zipcode ( 1900 - 1950)
p = sns.countplot(y="zipcode", data=new_df)
p.set_title(f"House count per zipcode ({building_age_min} - {building_age_max})")
p.set_xlabel("Count")
p.set_ylabel("Zipcode")
plt.show()
fig = p.get_figure()
fig.savefig("house_per_zi_best.png") 

color = sns.color_palette(["#bdbdbd", "#238b45"])
sns.set_palette(color)

p = sns.jointplot(x="lat", y="long", hue="is_best_grade", kind="kde", data=df)
#p.set_title(f"Houses ({building_age_min} - {building_age_max})")
p.set_axis_labels("Latidude (°)", "Longitude (°)")
plt.show()
p.savefig("house_per_area_best.png")

# %%
# Count historic buildings per zipcode
building_count = df.groupby("zipcode").count().sort_values("id", ascending=False)
building_count = building_count.reset_index()

# Extract zipcodes with highest count of historic buildings
building_count_zip = building_count.zipcode[building_count["id"] > 50]
print(building_count_zip)

# %%
# BEST TIME TO BUY / DATE

color = sns.color_palette(["#bdbdbd"])
sns.set_palette(color)

p = sns.histplot(x="date_month", bins=11, data=df)
#p.set_title(f"Sold houses per month ({building_age_min} - {building_age_max})")
p.set_title("Sold houses per month")
p.set_xlabel("Month")
p.set_ylabel("Count")
p.set_xlim(0,12)
p.set_ylim(0,700)
plt.show()
fig = p.get_figure()
fig.savefig("house_sales.png") 

color = sns.color_palette(["#238b45"])
sns.set_palette(color)

p = sns.histplot(x="date_month", bins=11, data=new_df)
#p.set_title(f"Sold houses per month ({building_age_min} - {building_age_max})")
p.set_title("Sold houses per month")
p.set_xlabel("Month")
p.set_ylabel("Count")
p.set_xlim(0,12)
p.set_ylim(0,700)
plt.show()
fig = p.get_figure()
fig.savefig("house_sales_best.png") 

#p = sns.histplot(x="date_month", bins=11, data=new_df)
#p.set_title(f"Sold houses per month ({building_age_min} - {building_age_max})")
#p.set_title("Sold houses per month")
#p.set_xlabel("Month")
#p.set_ylabel("Count")
#p.set_xlim(0,12)
#p.set_ylim(0,100)
#plt.show()
#fig = p.get_figure()
#fig.savefig("house_sales_best2.png")

# %%
# Check correlation with prize of: condition, grade, era, renovation
#df["condition"]

x = df["condition"]
#x = df["grade"]
#x = df["era_num"]
#x = df["is_renovated"]
y = df["price"]

np.corrcoef(x,y)
# Out:
# array([[1.        , 0.01350232],
#        [0.01350232, 1.        ]])

# %%
# Import GLM libraries
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# Fit GLM
formula = "price ~ condition"
#formula = "price ~  grade"
#formula = "price ~ condition * grade"
#formula = "price ~ era_num"
#formula = "price ~ is_renovated"
family = sm.families.Poisson()

mdl = smf.glm(formula, df, family=family).fit()
print(mdl.summary())
#print(mdl.pvalues.loc["condition"])
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  price   No. Observations:                 5184
# Model:                            GLM   Df Residuals:                     5182
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -4.7980e+08
# Date:                Fri, 15 Mar 2024   Deviance:                   9.5952e+08
# Time:                        13:30:56   Pearson chi2:                 1.34e+09
# No. Iterations:                     5   Pseudo R-squ. (CS):              1.000
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.6930   8.97e-05   1.42e+05      0.000      12.693      12.693
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5184 entries, 2 to 21567
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             5184 non-null   int64
#  1   bedrooms       5184 non-null   float64
#  2   bathrooms      5184 non-null   float64
#  3   sqft_living    5184 non-null   float64
#  4   sqft_lot       5184 non-null   float64
#  5   floors         5184 non-null   float64
#  6   waterfront     4601 non-null   float64
#  7   view           5168 non-null   float64
#  8   condition      5184 non-null   int64
#  9   grade          5184 non-null   int64
#  10  sqft_above     5184 non-null   float64
#  11  sqft_basement  5050 non-null   float64
#  12  yr_built       5184 non-null   int64
#  13  yr_renovated   4206 non-null   float64
#  14  zipcode        5184 non-null   int64
#  15  lat            5184 non-null   float64
#  16  long           5184 non-null   float64
# ...
